# %% [markdown]
# # Importing the necessary libraries :

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Creating a function to display images :

# %%
def display_img(img,cmap='gray'):
    fig=plt.figure(figsize=(10,12))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %% [markdown]
# # Reading the first image and display it :

# %%
reeses=cv2.imread('Chocolate_types.png',0)

# %%
display_img(reeses)

# %% [markdown]
# # Now is the second image :

# %%
cereals=cv2.imread('snickers_image.jpg',0)

# %%
display_img(cereals)

# %% [markdown]
# # Now creating the detector object :

# %%
orb=cv2.ORB_create()

# %% [markdown]
# # Now we find the key points & descriptors of this object :

# %%
kp1,des1=orb.detectAndCompute(reeses,None)

# %%
kp2,des2=orb.detectAndCompute(cereals,None)

# %% [markdown]
# # Creating the matching object by brute-force method :

# %%
bf=cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck=True)

# %% [markdown]
# # Now is to check where the matching occurs & display them :

# %%
matches=bf.match(des1,des2)

# %%
matches
# Out:
# [<DMatch 000001CEB1057FB0>,
#  <DMatch 000001CEB0A8DA30>,
#  <DMatch 000001CEB0A8D990>,
#  <DMatch 000001CEB0AEA430>,
#  <DMatch 000001CEB0AEAF50>,
#  <DMatch 000001CEB0AEAF70>,
#  <DMatch 000001CEB0AEAE70>,
#  <DMatch 000001CEB10CA710>,
#  <DMatch 000001CEB10CA950>,
#  <DMatch 000001CEB10CAAB0>,
#  <DMatch 000001CEB10CAAF0>,
#  <DMatch 000001CEB10CABF0>,
#  <DMatch 000001CEB10CACB0>,
#  <DMatch 000001CEB10CA890>,
#  <DMatch 000001CEB10CAC30>,
#  <DMatch 000001CEB10CAB50>,
#  <DMatch 000001CEB0D4F5D0>,
#  <DMatch 000001CEB0D4F150>,
#  <DMatch 000001CEB0D4FB30>,
#  <DMatch 000001CEB0D4F470>,
#  <DMatch 000001CEB0D4FA30>,
#  <DMatch 000001CEB0D4F2B0>,
#  <DMatch 000001CEB0D4F570>,
#  <DMatch 000001CEB0D4FB50>,
#  <DMatch 000001CEB0D4F370>,
#  <DMatch 000001CEB0D4F650>,
#  <DMatch 000001CEB0AF6410>,
#  <DMatch 000001CEB0AF6430>,
#  <DMatch 000001CEB0AF6450>,
#  <DMatch 000001CEB0AF6470>,
#  <DMatch 000001CEB0AF6490>,
#  <DMatch 000001CEB0AF64B0>,
#  <DMatch 000001CEB0AF64D0>,
# ...

# %% [markdown]
# # Now let's view the first matching & view it's distance :

# %%
single_match=matches[0]

# %% [markdown]
# # When the distance value is less, means the the matching is better :

# %%
single_match.distance
# Out:
# 28.0

# %% [markdown]
# # Let's sort the matches based on the distance :

# %%
matches=sorted(matches,key=lambda x:x.distance)

# %% [markdown]
# # Let's view the length of the matches :

# %%
len(matches)
# Out:
# 142

# %% [markdown]
# # Now let's draw the matches of the first 25 only :

# %%
reeses_matches=cv2.drawMatches(reeses,kp1,cereals,kp2,matches[:25],None,flags=2)

# %% [markdown]
# # Now let's display the draw matches :

# %%
display_img(reeses_matches)
